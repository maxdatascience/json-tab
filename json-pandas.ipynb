# %%
import pandas as pd
in_url = input().strip()
out_url = in_url[:-4]+"csv"

# %%
df = pd.read_json(in_url)
print(df.shape)
print(df.dtypes)
print(df.describe())
slug_name = df[['slug', 'name', 'available']]
df.set_index(['slug', 'name'],inplace=True)
df.head()
# Out:
# (14, 5)
# slug          object
# name          object
# sizes         object
# available    float64
# features      object
# dtype: object
#        available
# count       11.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
#                                                                   sizes  \
# slug name
# nyc1 New York 1       [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# sfo1 San Francisco 1                                                NaN
# nyc2 New York 2                                                     NaN
# ams2 Amsterdam 2                                                    NaN
# sgp1 Singapore 1      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
#
#                       available  \
# slug name
# nyc1 New York 1             1.0
# sfo1 San Francisco 1        NaN
# nyc2 New York 2             NaN
# ams2 Amsterdam 2            NaN
# sgp1 Singapore 1            1.0
#
# ...

# %%
brief_droplets = df.sort_index(level=['slug', 'name'])
df.reset_index()
brief_droplets
# Out:
#                                                                   sizes  \
# slug name
# ams2 Amsterdam 2                                                    NaN
# ams3 Amsterdam 3      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# blr1 Bangalore 1      [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# fra1 Frankfurt 1      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# lon1 London 1         [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# nyc1 New York 1       [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# nyc2 New York 2                                                     NaN
# nyc3 New York 3       [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# sfo1 San Francisco 1                                                NaN
# sfo2 San Francisco 2  [s-1vcpu-1gb, s-1vcpu-2gb, s-2vcpu-2gb, s-2vcp...
# sfo3 San Francisco 3  [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# sgp1 Singapore 1      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# ...

# %%
mask = brief_droplets['available'] == 1.0
brief_droplets.loc[mask, 'available'] = True
mask = brief_droplets['available'] != 1.0
brief_droplets.loc[mask,'available'] = False
brief_droplets
# Out:
# /tmp/ipykernel_22241/276953541.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   brief_droplets.loc[mask, 'available'] = True
#                                                                   sizes  \
# slug name
# ams2 Amsterdam 2                                                    NaN
# ams3 Amsterdam 3      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# blr1 Bangalore 1      [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# fra1 Frankfurt 1      [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# lon1 London 1         [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# nyc1 New York 1       [s-1vcpu-512mb-10gb, s-1vcpu-1gb, s-1vcpu-1gb-...
# nyc2 New York 2                                                     NaN
# nyc3 New York 3       [s-1vcpu-1gb, s-1vcpu-1gb-amd, s-1vcpu-1gb-int...
# ...

# %%
# df.set_index(['slug'])
sizes = df.loc['fra1']['sizes']
print(list(sizes))
sizes
# Out:
# [['s-1vcpu-512mb-10gb', 's-1vcpu-1gb', 's-1vcpu-1gb-amd', 's-1vcpu-1gb-intel', 's-1vcpu-1gb-35gb-intel', 's-1vcpu-2gb', 's-1vcpu-2gb-amd', 's-1vcpu-2gb-intel', 's-1vcpu-2gb-70gb-intel', 's-2vcpu-2gb', 's-2vcpu-2gb-amd', 's-2vcpu-2gb-intel', 's-2vcpu-2gb-90gb-intel', 's-2vcpu-4gb', 's-2vcpu-4gb-amd', 's-2vcpu-4gb-intel', 's-2vcpu-4gb-120gb-intel', 's-2vcpu-8gb-amd', 'c-2', 'c2-2vcpu-4gb', 's-2vcpu-8gb-160gb-intel', 's-4vcpu-8gb', 's-4vcpu-8gb-amd', 's-4vcpu-8gb-intel', 'g-2vcpu-8gb', 's-4vcpu-8gb-240gb-intel', 'gd-2vcpu-8gb', 'g-2vcpu-8gb-intel', 'gd-2vcpu-8gb-intel', 's-4vcpu-16gb-amd', 'm-2vcpu-16gb', 'c-4', 'c2-4vcpu-8gb', 's-4vcpu-16gb-320gb-intel', 's-8vcpu-16gb', 'm-2vcpu-16gb-intel', 'm3-2vcpu-16gb', 'c-4-intel', 'm3-2vcpu-16gb-intel', 's-8vcpu-16gb-amd', 's-8vcpu-16gb-intel', 'c2-4vcpu-8gb-intel', 'g-4vcpu-16gb', 's-8vcpu-16gb-480gb-intel', 'so-2vcpu-16gb-intel', 'so-2vcpu-16gb', 'm6-2vcpu-16gb', 'gd-4vcpu-16gb', 'so1_5-2vcpu-16gb-intel', 'g-4vcpu-16gb-intel', 'gd-4vcpu-16gb-i
# ...

# %%
# brief = df[['slug', 'name']]
# brief
slug_name.sort_values('slug')
# Out:
#     slug             name  available
# 3   ams2      Amsterdam 2        NaN
# 7   ams3      Amsterdam 3        1.0
# 11  blr1      Bangalore 1        1.0
# 8   fra1      Frankfurt 1        1.0
# 5   lon1         London 1        1.0
# 0   nyc1       New York 1        1.0
# 2   nyc2       New York 2        NaN
# 6   nyc3       New York 3        1.0
# 1   sfo1  San Francisco 1        NaN
# 10  sfo2  San Francisco 2        1.0
# 12  sfo3  San Francisco 3        1.0
# 4   sgp1      Singapore 1        1.0
# 13  syd1         Sydney 1        1.0
# 9   tor1        Toronto 1        1.0
